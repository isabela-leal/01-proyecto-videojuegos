# %% [markdown]
# # 📊 Proyecto Guiado - Análisis de Ventas de Videojuegos
# ## Parte 1: Introducción y Carga de Datos
#
# ---
#
# ### 🎯 Objetivos de este notebook:
# 1. Entender qué es un EDA (Exploratory Data Analysis)
# 2. Aprender a cargar datos desde archivos CSV
# 3. Realizar una primera inspección de los datos
# 4. Identificar las características del dataset
#
# ---
#
# ### 📚 ¿Qué es un EDA?
#
# El **Análisis Exploratorio de Datos (EDA)** es el proceso de:
# - Examinar los datos antes de construir modelos
# - Descubrir patrones, anomalías y relaciones
# - Formular hipótesis sobre los datos
# - Verificar suposiciones mediante visualizaciones y estadísticas
#
# **¿Por qué es importante?**
# - Nos ayuda a entender nuestros datos
# - Detecta problemas de calidad (datos faltantes, duplicados, errores)
# - Guía las decisiones sobre limpieza y preparación
# - Revela insights valiosos para el negocio

# %% [markdown]
# ---
# ## 1. Importar las librerías necesarias
#
# Comenzamos importando las librerías que usaremos:
# - **pandas**: Para manipulación y análisis de datos
# - **numpy**: Para operaciones numéricas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
# ## 2. Cargar el dataset
#
# Vamos a cargar el archivo CSV con datos de ventas de videojuegos.
#
# **Información sobre el dataset:**
# - **Fuente**: Kaggle - Video Game Sales Dataset
# - **Período**: Ventas de videojuegos hasta 2016
# - **Contenido**: Ranking, nombre, plataforma, año, género, publisher y ventas por región

# %%
# Cargar el dataset desde el archivo CSV
df = pd.read_csv(r'C:\Users\Propietario\OneDrive\Escritorio\Data_analysis\Modulo_1\7.Proyectos guiados\vgsales.csv')

# %% [markdown]
# ---
# ## 3. Primera inspección: Ver las primeras filas
#
# El método `.head()` nos muestra las primeras 5 filas por defecto.
# Esto nos da una idea rápida de cómo se ven nuestros datos.

# %%
# Visualizar las primeras 10 filas del dataset
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %% [markdown]
# ### 🔍 ¿Qué observamos?

# %% [markdown]
# ---
# ## 4. Ver las últimas filas
#
# El método `.tail()` nos muestra las últimas filas.
# Útil para ver juegos con menor ranking.

# %%
# Visualizar las últimas 10 filas del dataset
df.tail(10)
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %% [markdown]
# ---
# ## 5. Información general del dataset
#
# El método `.info()` nos proporciona:
# - Número total de entradas (filas)
# - Tipos de datos de cada columna
# - Cantidad de valores no nulos
# - Uso de memoria

# %%
# Información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# ---
# ## 6. Dimensiones del dataset
#
# Vamos a obtener información sobre el tamaño de nuestro dataset.

# %%
# Obtener dimensiones
df.shape  


#Otra forma 
num_filas , num_columnas = df.shape

print(f'Dimensiones del dartaset: {num_filas} filas y {num_columnas} columnas')
print(f'Número de registros (filas): {num_filas}')
print(f'Número de variables (columnas): {num_columnas}')
print(f"Total de celdas: {num_filas * num_columnas}")
# Out:
# Dimensiones del dartaset: 16598 filas y 11 columnas
# Número de registros (filas): 16598
# Número de variables (columnas): 11
# Total de celdas: 182578

# %% [markdown]
# ---
# ## 8. Tipos de datos
#
# Vamos a examinar los tipos de datos de cada columna de forma detallada.

# %%
# Mostrar tipos de datos
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# ---
# ## 9. Vista aleatoria de los datos
#
# El método `.sample()` nos permite ver filas aleatorias.
# Esto es útil para obtener una muestra representativa.

# %%
# Mostrar 10 filas aleatorias
df.sample(10)
# Out:
#         Rank                                        Name Platform    Year  \
# 5111    5113       Prince of Persia: The Forgotten Sands      PSP  2010.0
# 95        96      Crash Bandicoot 2: Cortex Strikes Back       PS  1997.0
# 2354    2356  Mega Man 8 Anniversary Collector's Edition       PS  1996.0
# 15371  15374                  Jewel Link: Galactic Quest       DS  2012.0
# 16386  16389                            TrackMania Turbo       PC  2016.0
# 4693    4695          Tom Clancy's Rainbow Six: Lockdown       XB  2005.0
# 6660    6662                           Just Dance Kids 2      PS3  2011.0
# 6851    6853                        Dragon Ball Z: Sagas       XB  2005.0
# 15425  15428                                      Malice      PS2  2004.0
# 15        16                          Kinect Adventures!     X360  2010.0
#
#           Genre                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 5111     Action                      Ubisoft      0.09      0.18      0.01
# ...

# %% [markdown]
# ---
# ## 10. Nombres de las columnas
#
# Verificar los nombres exactos de las columnas es importante para evitar errores.

# %%
# Listar todas las columnas
print ( )


df.columns
# También podemos verlas como lista
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')
